# %% [markdown]
# This project will aim to analyze the eBay listing for used cars.
# The project is explorative, and aims to gain general insighht into data.
# The project is used as a context to practice the Pandas and NumPy libraries for Python.

# %% [markdown]
# # 1. Set up and inspection
# First we will set up the project: importing the respective libraries, and inspecting the data.

# %%
#importing libraries

import pandas as pd
import numpy as np

autos = pd.read_csv('autos.csv', encoding = 'Latin-1')

# %%
# observing the data
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
#        seller offerType    price   abtest vehicleType  yearOfRegistration  \
# 0      privat   Angebot   $5,000  control         bus                2004
# 1      privat   Angebot   $8,500  control   limousine                1997
# 2      privat   Angebot   $8,990     test   limousine                2009
# 3      privat   Angebot   $4,350  control  kleinwagen                2007
# 4      privat   Angebot   $1,350     test       kombi                2003
# ...       ...       ...      ...      ...         ...                 ...
# 49995  privat   Angebot  $24,900  control   limousine                2011
# 49996  privat   Angebot   $1,980  control      cabrio                1996
# 49997  privat   Angebot  $13,200     test      cabrio                2014
# 49998  privat   Angebot  $22,900  control       kombi                2013
# 49999  privat   Angebot   $1,250  control   limousine                1996
#
#          gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# 0        manuell      158  andere  150,000km                    3      lpg
# 1      automatik      286     7er  150,000km                    6   benzin
# 2        manuell      102    golf   70,000km                    7   benzin
# 3      automatik       71  fortwo   70,000km                    6   benzin
# 4        manuell        0   focus  150,000km                    7   benzin
# ...          ...      ...     ...        ...                  ...      ...
# 49995  automatik      239      q5  100,000km                    1   diesel
# 49996    manuell       75   astra  150,000km                    5   benzin
# 49997  automatik       69     500    5,000km                   11   benzin
# 49998    manuell      150      a3   40,000km                   11   diesel
# 49999    manuell      101  vectra  150,000km                    1   benzin
#
#             brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0         peugeot              nein  2016-03-26 00:00:00             0
# 1             bmw              nein  2016-04-04 00:00:00             0
# 2      volkswagen              nein  2016-03-26 00:00:00             0
# 3           smart              nein  2016-03-12 00:00:00             0
# 4            ford              nein  2016-04-01 00:00:00             0
# ...           ...               ...                  ...           ...
# 49995        audi              nein  2016-03-27 00:00:00             0
# 49996        opel              nein  2016-03-28 00:00:00             0
# 49997        fiat              nein  2016-04-02 00:00:00             0
# 49998        audi              nein  2016-03-08 00:00:00             0
# 49999        opel              nein  2016-03-13 00:00:00             0
#
#        postalCode             lastSeen
# 0           79588  2016-04-06 06:45:54
# 1           71034  2016-04-06 14:45:08
# 2           35394  2016-04-06 20:15:37
# 3           33729  2016-03-15 03:16:28
# 4           39218  2016-04-01 14:38:50
# ...           ...                  ...
# 49995       82131  2016-04-01 13:47:40
# 49996       44807  2016-04-02 14:18:02
# 49997       73430  2016-04-04 11:47:27
# 49998       35683  2016-04-05 16:45:07
# 49999       45897  2016-04-06 21:18:48
#
# [50000 rows x 20 columns]

# %%
# observing summary of columns
print(autos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
#  15  notRepairedDamage    40171 non-null  object
#  16  dateCreated          50000 non-null  object
#  17  nrOfPictures         50000 non-null  int64
#  18  postalCode           50000 non-null  int64
#  19  lastSeen             50000 non-null  object
# dtypes: int64(5), object(15)
# memory usage: 7.6+ MB
# None

# %% [markdown]
# We can see that we have all 20 columns, which are mostly non-null. (most null is for notRepairedDamage).

# %%
#observing the top rows
print(autos.head(5))
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# 0    manuell      158  andere  150,000km                    3      lpg
# 1  automatik      286     7er  150,000km                    6   benzin
# 2    manuell      102    golf   70,000km                    7   benzin
# 3  automatik       71  fortwo   70,000km                    6   benzin
# 4    manuell        0   focus  150,000km                    7   benzin
#
#         brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0     peugeot              nein  2016-03-26 00:00:00             0
# 1         bmw              nein  2016-04-04 00:00:00             0
# 2  volkswagen              nein  2016-03-26 00:00:00             0
# 3       smart              nein  2016-03-12 00:00:00             0
# 4        ford              nein  2016-04-01 00:00:00             0
#
#    postalCode             lastSeen
# 0       79588  2016-04-06 06:45:54
# 1       71034  2016-04-06 14:45:08
# 2       35394  2016-04-06 20:15:37
# 3       33729  2016-03-15 03:16:28
# 4       39218  2016-04-01 14:38:50

# %% [markdown]
# The rows seem to have certain data types which could be converted to floats/integers for better analysis (e.g price) and odomoter values.
# The date and time is also read out as a string. We can utilise the datetime libraries in order to operate on these dates more efficiently.
#
# The row of 'notRepairedDamage' can also be converted into boolean, since it is currently stored as 'yes/no'.

# %% [markdown]
# Now looking at the describe statistics.

# %%
autos.describe(include='all')
# Out:
#                 dateCrawled         name  seller offerType  price abtest  \
# count                 50000        50000   50000     50000  50000  50000
# unique                48213        38754       2         2   2357      2
# top     2016-03-08 10:40:35  Ford_Fiesta  privat   Angebot     $0   test
# freq                      3           78   49999     49999   1421  25756
# mean                    NaN          NaN     NaN       NaN    NaN    NaN
# std                     NaN          NaN     NaN       NaN    NaN    NaN
# min                     NaN          NaN     NaN       NaN    NaN    NaN
# 25%                     NaN          NaN     NaN       NaN    NaN    NaN
# 50%                     NaN          NaN     NaN       NaN    NaN    NaN
# 75%                     NaN          NaN     NaN       NaN    NaN    NaN
# max                     NaN          NaN     NaN       NaN    NaN    NaN
#
#        vehicleType  yearOfRegistration  gearbox       powerPS  model  \
# count        44905        50000.000000    47320  50000.000000  47242
# unique           8                 NaN        2           NaN    245
# top      limousine                 NaN  manuell           NaN   golf
# freq         12859                 NaN    36993           NaN   4024
# mean           NaN         2005.073280      NaN    116.355920    NaN
# std            NaN          105.712813      NaN    209.216627    NaN
# min            NaN         1000.000000      NaN      0.000000    NaN
# 25%            NaN         1999.000000      NaN     70.000000    NaN
# 50%            NaN         2003.000000      NaN    105.000000    NaN
# 75%            NaN         2008.000000      NaN    150.000000    NaN
# max            NaN         9999.000000      NaN  17700.000000    NaN
#
#          odometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# count       50000         50000.000000    45518       50000             40171
# unique         13                  NaN        7          40                 2
# top     150,000km                  NaN   benzin  volkswagen              nein
# freq        32424                  NaN    30107       10687             35232
# mean          NaN             5.723360      NaN         NaN               NaN
# std           NaN             3.711984      NaN         NaN               NaN
# min           NaN             0.000000      NaN         NaN               NaN
# 25%           NaN             3.000000      NaN         NaN               NaN
# 50%           NaN             6.000000      NaN         NaN               NaN
# 75%           NaN             9.000000      NaN         NaN               NaN
# max           NaN            12.000000      NaN         NaN               NaN
#
#                 dateCreated  nrOfPictures    postalCode             lastSeen
# count                 50000       50000.0  50000.000000                50000
# unique                   76           NaN           NaN                39481
# top     2016-04-03 00:00:00           NaN           NaN  2016-04-07 06:17:27
# freq                   1946           NaN           NaN                    8
# mean                    NaN           0.0  50813.627300                  NaN
# std                     NaN           0.0  25779.747957                  NaN
# min                     NaN           0.0   1067.000000                  NaN
# 25%                     NaN           0.0  30451.000000                  NaN
# 50%                     NaN           0.0  49577.000000                  NaN
# 75%                     NaN           0.0  71540.000000                  NaN
# max                     NaN           0.0  99998.000000                  NaN

# %% [markdown]
# To be consistentwith formatting we will use snakecase rather than Camelcase throughout the project. Hence we will rename the headers for the columns.

# %%
print(autos.columns)
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
#use the following rename dictionary to swap column names
mapping = {
    'dateCrawled':'date_crawled',
    'name':'name',
    'seller':'seller',
    'offerType':'offer_type',
    'price':'price',
    'abtest':'abtest',
    'vehicleType':'vehicle_type',
    'yearOfRegistration':'registration_year',
    'gearbox':'gearbox',
    'powerPS':'powerPS',
    'model':'model',
    'odometer':'odometer',
    'monthOfRegistration':'registration_month',
    'fuelType':'fuel_type',
    'brand':'brand',
    'notRepairedDamage':'unrepaired_damage',
    'dateCreated':'ad_created',
    'nrOfPictures':'nr_of_pictures',
    'postalCode':'postal_code',
    'lastSeen':'last_seen'
}

# %%
autos.rename(columns=mapping, inplace=True)
print(autos.columns)
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'powerPS', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# Columns succesfully renamed.

# %% [markdown]
# # 2. Cleaning the data

# %% [markdown]
# We wil now look at the data itself, and perform any preliminary cleaning that ought to be done before analysis.

# %%
autos.describe()
# Out:
#        registration_year       powerPS  registration_month  nr_of_pictures  \
# count       50000.000000  50000.000000        50000.000000         50000.0
# mean         2005.073280    116.355920            5.723360             0.0
# std           105.712813    209.216627            3.711984             0.0
# min          1000.000000      0.000000            0.000000             0.0
# 25%          1999.000000     70.000000            3.000000             0.0
# 50%          2003.000000    105.000000            6.000000             0.0
# 75%          2008.000000    150.000000            9.000000             0.0
# max          9999.000000  17700.000000           12.000000             0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %% [markdown]
# Looking at the headline figures, we make a the following oservations:
# 1. The nr_of_pictures is all 0 , indicating either a data collection error (unlikely that for all listings there are 0 pictures on ebay)
# 2. Registration year will require investigation, as the minimum registration year is seen as 1000 - unlikely , given that the first car was invented in 1885.
# 3. There might be missing registration months as well, given that theese can only have values 1-12 , whereas we see a minimum values of 0. It is possible that the nulls are stored as -.
# 4. The 'autos.describe' returns the summary statistics of the values stored as floats. Comparing this to 'autos.info' we can see that some of the columns, which we'd expect to be useful to interpret as floats/integeres are stored as strings. These for example, include the 'price' and 'odometer' columns, as these include the currency symbols and distance units

# %% [markdown]
# In order to prepare the data for analysis, we will remove the unit descriptors from the individual rows (separating them), and convert the columns into floats.
#
# We also notice that there are ',' (commas) used in order to seperate the 1000s. We will also remove those to allow for float analysis.

# %% [markdown]
# First we convert  the price columns to flot figures

# %%
#converting the price column from 'object' to 'string' type
autos['price'] = autos['price'].astype(str)

#applying string operations

autos['price'] = autos['price'].str.replace('$','')
autos['price'] = autos['price'].str.replace(',','')
autos['price'] = autos['price'].astype(int)

#inspecting the data after conversion
autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %% [markdown]
# Now we convert the odometeer reading column to float values, removing the distance units, and comma 1000s separator. We will also rename the column header from 'odometer' to 'odometer_km' to preserve the information that the values are stored in kilometers

# %%
#converting the odometer column from 'object' to 'string' type
autos['odometer'] = autos['odometer'].astype(str)

#applying string operations

autos['odometer'] = autos['odometer'].str.replace('km','')
autos['odometer'] = autos['odometer'].str.replace(',','')
autos['odometer'] = autos['odometer'].astype(int)

#inspecting the data after conversion
autos['odometer'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer, dtype: float64

# %%
# 
autos.rename({'odometer' : 'odometer_km'}, axis = 1,  inplace = True)

print(autos.columns)
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'powerPS', 'model',
#        'odometer_km', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# We have now converted the numeric columns to store numeric float values, rather than objects.

# %% [markdown]
# We will now clean the price and odomoter values , and look at outliers.

# %% [markdown]
# ## Cleaning the price values
#
#
# Inspecting the price first, we see that we have '0' values:

# %%
autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos['price'].value_counts().sort_index(ascending=True)
# Out:
# 0           1421
# 1            156
# 2              3
# 3              1
# 5              2
#             ...
# 10000000       1
# 11111111       2
# 12345678       3
# 27322222       1
# 99999999       1
# Name: price, Length: 2357, dtype: int64

# %% [markdown]
# We will inspect the most expensive entries (above 1m).

# %%
autos.loc[autos['price'] > 1000000]
# Out:
#               date_crawled                                               name  \
# 2897   2016-03-12 21:50:57   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000
# 7814   2016-04-04 11:53:31                                        Ferrari_F40
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# 22947  2016-03-22 12:54:19                         Bmw_530d_zum_ausschlachten
# 24384  2016-03-21 13:57:51                            Schlachte_Golf_3_gt_tdi
# 27371  2016-03-09 15:45:47                                         Fiat_Punto
# 39377  2016-03-08 23:53:51                        Tausche_volvo_v40_gegen_van
# 39705  2016-03-22 14:58:27                        Tausch_gegen_gleichwertiges
# 42221  2016-03-08 20:39:05                                  Leasinguebernahme
# 47598  2016-03-31 18:56:54  Opel_Vectra_B_1_6i_16V_Facelift_Tuning_Showcar...
# 47634  2016-04-04 21:25:21                                        Ferrari_FXX
#
#        seller offer_type     price   abtest vehicle_type  registration_year  \
# 2897   privat    Angebot  11111111     test    limousine               1973
# 7814   privat    Angebot   1300000  control        coupe               1992
# 11137  privat    Angebot  10000000  control        coupe               1960
# 22947  privat    Angebot   1234566  control        kombi               1999
# 24384  privat    Angebot  11111111     test          NaN               1995
# 27371  privat    Angebot  12345678  control          NaN               2017
# 39377  privat    Angebot  12345678  control          NaN               2018
# 39705  privat    Angebot  99999999  control    limousine               1999
# 42221  privat    Angebot  27322222  control    limousine               2014
# 47598  privat    Angebot  12345678  control    limousine               2001
# 47634  privat    Angebot   3890000     test        coupe               2006
#
#          gearbox  powerPS     model  odometer_km  registration_month  \
# 2897     manuell       48    escort        50000                   3
# 7814         NaN        0       NaN        50000                  12
# 11137    manuell      368       NaN       100000                   1
# 22947  automatik      190       NaN       150000                   2
# 24384        NaN        0       NaN       150000                   0
# 27371        NaN       95     punto       150000                   0
# 39377    manuell       95       v40       150000                   6
# 39705  automatik      224  s_klasse       150000                   9
# 42221    manuell      163        c4        40000                   2
# 47598    manuell      101    vectra       150000                   3
# 47634        NaN      799       NaN         5000                   7
#
#       fuel_type           brand unrepaired_damage           ad_created  \
# 2897     benzin            ford              nein  2016-03-12 00:00:00
# 7814        NaN  sonstige_autos              nein  2016-04-04 00:00:00
# 11137    benzin  sonstige_autos              nein  2016-03-29 00:00:00
# 22947    diesel             bmw               NaN  2016-03-22 00:00:00
# 24384       NaN      volkswagen               NaN  2016-03-21 00:00:00
# 27371       NaN            fiat               NaN  2016-03-09 00:00:00
# 39377       NaN           volvo              nein  2016-03-08 00:00:00
# 39705    benzin   mercedes_benz               NaN  2016-03-22 00:00:00
# 42221    diesel         citroen               NaN  2016-03-08 00:00:00
# 47598    benzin            opel              nein  2016-03-31 00:00:00
# 47634       NaN  sonstige_autos              nein  2016-04-04 00:00:00
#
#        nr_of_pictures  postal_code            last_seen
# 2897                0        94469  2016-03-12 22:45:27
# 7814                0        60598  2016-04-05 11:34:11
# 11137               0        73033  2016-04-06 21:18:11
# 22947               0        17454  2016-04-02 03:17:32
# 24384               0        18519  2016-03-21 14:40:18
# 27371               0        96110  2016-03-09 15:45:47
# 39377               0        14542  2016-04-06 23:17:31
# 39705               0        73525  2016-04-06 05:15:30
# 42221               0        76532  2016-03-08 20:39:05
# 47598               0         4356  2016-03-31 18:56:54
# 47634               0        60313  2016-04-05 12:07:37

# %% [markdown]
# At this price point we expect sports/collector cars, however we see that there is a number of cars that we do not expect at that price point (such as a golf TDI, or an old volvo v40). We will remove these rows from the datastet ( these could have been either a bad entry in price, or intentional to gain attention).

# %%
#dropping the head values of price
autos.drop([2897], inplace = True)
autos.drop([22947], inplace = True)
autos.drop([24384], inplace = True)
autos.drop([27371], inplace = True)
autos.drop([39377], inplace = True)
autos.drop([39705], inplace = True)
autos.drop([42221], inplace = True)
autos.drop([47598], inplace = True)
autos.drop([11137], inplace = True) #overpriced maserati (1 too many zeroes)

# %% [markdown]
# Inspecting further the range of values.
# Looking at the range of values we see that there is a number of cars with a price of '< 1000\\$' - we will set the minimum price at 1000\$, since it is unlikely that the cars priced belo w the price point are realised offers. The listing include bidding pages, and so it is possible that sellers had set an initial bidding price very low (e.g at 1\$). We wil exclude these lower price ranges, as this would skew the analysis with listing that currently have low bids, or that have just been listed.

# %%
#setting a minimum price of 1000$

autos = autos[autos['price'] > 1000]

#inspecting final set

print(autos['price'].value_counts().sort_index(ascending=True).head(5))
print(autos['price'].value_counts().sort_index(ascending=True).tail(5))
# Out:
# 1039     1
# 1040     1
# 1049     6
# 1050    95
# 1059     1
# Name: price, dtype: int64
# 350000     1
# 999990     1
# 999999     2
# 1300000    1
# 3890000    1
# Name: price, dtype: int64

# %%
autos['price'].describe()
# Out:
# count    3.799200e+04
# mean     7.575204e+03
# std      2.476903e+04
# min      1.039000e+03
# 25%      2.300000e+03
# 50%      4.499000e+03
# 75%      8.999000e+03
# max      3.890000e+06
# Name: price, dtype: float64

# %% [markdown]
# #### Findings:
# - We note that the current values can also include prices that are currently being bid (which can skew the price downwards, as the final settlement price is still being reached).
# - The mean price is 7575.20\$
# - Outliers had been removed

# %% [markdown]
# ## Cleaning the odometer values
# We will now inspect the range of odomoter values to ensure that they are within expected ranges.

# %%
autos['odometer_km'].describe()
# Out:
# count     37992.000000
# mean     122490.919141
# std       40899.765790
# min        5000.000000
# 25%      100000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos['odometer_km'].value_counts().sort_index(ascending=False)
# Out:
# 150000    22776
# 125000     4300
# 100000     1852
# 90000      1560
# 80000      1326
# 70000      1153
# 60000      1093
# 50000       982
# 40000       795
# 30000       747
# 20000       688
# 10000       227
# 5000        493
# Name: odometer_km, dtype: int64

# %% [markdown]
# #### Findings:
# - There are no significant outliers in the odometer value ranges
# - There a proportionately more cares with as mileage increases (which is to be expectedm, as ebay is used to sell also used cars)

# %% [markdown]
# ## Cleaning the Date values

# %% [markdown]
# We now turn our attention towards the columns containing date and time information, to ensure that the values are stored are well-behaved.

# %% [markdown]
# The columns containing date information are as follows:
#
# - `date_crawled`: added by the crawler
# - `last_seen`: added by the crawler
# - `ad_created`: from the website
# - `registration_month`: from the website
# - `registration_year`: from the website

# %%
autos[['date_crawled','last_seen',
      'ad_created','registration_month',
      'registration_year']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37992 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date_crawled        37992 non-null  object
#  1   last_seen           37992 non-null  object
#  2   ad_created          37992 non-null  object
#  3   registration_month  37992 non-null  int64
#  4   registration_year   37992 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 1.7+ MB

# %% [markdown]
# Inspecting the columns of the autos dataset, we see that'date crawled' , 'last_seen', and 'ad_created' columns store strings.

# %% [markdown]
# Let us take a sample of the columns which store these objects.

# %%
autos[['date_crawled','last_seen',
      'ad_created']].head(5)
# Out:
#           date_crawled            last_seen           ad_created
# 0  2016-03-26 17:47:46  2016-04-06 06:45:54  2016-03-26 00:00:00
# 1  2016-04-04 13:38:56  2016-04-06 14:45:08  2016-04-04 00:00:00
# 2  2016-03-26 18:57:24  2016-04-06 20:15:37  2016-03-26 00:00:00
# 3  2016-03-12 16:58:10  2016-03-15 03:16:28  2016-03-12 00:00:00
# 4  2016-04-01 14:38:50  2016-04-01 14:38:50  2016-04-01 00:00:00

# %% [markdown]
# We observe that the first 10 characters in each row represent the date input, in each of the columns. The remainder is used for time storage. We will use the first 10 characters in each row, to perform our analysis.

# %% [markdown]
# We will now take a close look at the dsitrivution of values in terms of dates, for the dataframe.

# %%
# Removing time values from the dataframe
print('Crawl Dates')
print(autos['date_crawled'].str[:10].value_counts(normalize=True, dropna=False).sort_index(ascending=True))

#last_seen dates distribution
print('last_seen Dates')
print(autos['last_seen'].str[:10].value_counts(normalize=True, dropna=False).sort_index(ascending=True))

#ad_created dates distribution
print('ad_created dates')
print(autos['ad_created'].str[:10].value_counts(normalize=True, dropna=False).sort_index(ascending=True))
# Out:
# Crawl Dates
# 2016-03-05    0.025716
# 2016-03-06    0.014003
# 2016-03-07    0.035455
# 2016-03-08    0.032349
# 2016-03-09    0.032481
# 2016-03-10    0.033270
# 2016-03-11    0.032954
# 2016-03-12    0.037640
# 2016-03-13    0.016056
# 2016-03-14    0.036771
# 2016-03-15    0.033507
# 2016-03-16    0.029032
# 2016-03-17    0.030164
# 2016-03-18    0.012924
# 2016-03-19    0.035113
# 2016-03-20    0.038245
# 2016-03-21    0.037324
# 2016-03-22    0.032559
# 2016-03-23    0.032059
# 2016-03-24    0.028796
# 2016-03-25    0.030296
# 2016-03-26    0.033139
# 2016-03-27    0.031454
# 2016-03-28    0.035350
# 2016-03-29    0.034060
# 2016-03-30    0.032954
# 2016-03-31    0.031401
# 2016-04-01    0.034560
# 2016-04-02    0.036376
# 2016-04-03    0.039245
# 2016-04-04    0.036771
# 2016-04-05    0.013240
# 2016-04-06    0.003238
# 2016-04-07    0.001500
# Name: date_crawled, dtype: float64
# last_seen Dates
# 2016-03-05    0.001105
# 2016-03-06    0.003553
# 2016-03-07    0.004501
# 2016-03-08    0.006264
# 2016-03-09    0.008923
# 2016-03-10    0.009686
# 2016-03-11    0.011687
# 2016-03-12    0.022215
# 2016-03-13    0.008318
# 2016-03-14    0.012055
# 2016-03-15    0.014898
# 2016-03-16    0.015477
# 2016-03-17    0.026190
# 2016-03-18    0.007370
# 2016-03-19    0.014556
# 2016-03-20    0.019609
# 2016-03-21    0.019530
# 2016-03-22    0.020768
# 2016-03-23    0.017951
# 2016-03-24    0.018530
# 2016-03-25    0.017714
# 2016-03-26    0.015951
# 2016-03-27    0.014029
# 2016-03-28    0.019425
# 2016-03-29    0.020583
# 2016-03-30    0.023479
# 2016-03-31    0.022794
# 2016-04-01    0.023242
# 2016-04-02    0.024926
# 2016-04-03    0.024558
# 2016-04-04    0.023215
# 2016-04-05    0.131580
# 2016-04-06    0.234734
# 2016-04-07    0.140582
# Name: last_seen, dtype: float64
# ad_created dates
# 2015-06-11    0.000026
# 2015-08-10    0.000026
# 2015-09-09    0.000026
# 2015-11-10    0.000026
# 2015-12-30    0.000026
#                 ...
# 2016-04-03    0.039535
# 2016-04-04    0.037218
# 2016-04-05    0.011845
# 2016-04-06    0.003343
# 2016-04-07    0.001316
# Name: ad_created, Length: 74, dtype: float64

# %%
#Analysing the registration year
print(autos['registration_year'].value_counts(normalize=True, dropna=False).sort_index(ascending=True))
# Out:
# 1000    0.000026
# 1001    0.000026
# 1927    0.000026
# 1929    0.000026
# 1931    0.000026
#           ...
# 5911    0.000026
# 6200    0.000026
# 8888    0.000026
# 9000    0.000026
# 9999    0.000053
# Name: registration_year, Length: 91, dtype: float64

# %% [markdown]
# ### Observations:
# #### Crawl dates
# The crawl has been performed from 5th of march to 7th of April, and is roughly evenly distributed, with the exception of the last crawls in april.|
#
# The data was crawled every day from  5 March 2016 and ending at 7 April 2016.
#
# #### Last Seen dates
# The last_seen column denotes when the crawler saw thi ad last online.
# There is a signifact fall off of this in 3 days of posting. This is expected as newly posted vehicles need time to sell. This also might indicate the cars close on offers quite commonly in 3/4 days of posting, and the ad is then closed. The Older the timeframe, the less frequent this occurence is. These rows would also include if a listing was re-posted.
#
# #### Ad Created dates
# The older the the ad, the less entries obtain. This is to be expected as older postings are taken off / the cars get sold over time.
#
# #### Registration year
# There is a portion of cars where the registration date is out of expected values.
# These include '1000' & '1001' and years going past 2016.
# We also have entires where registration year is '2100+' ; which might be indicating an unregistered vehicle.
# The cars registered at these dates consitute a small portion of the entire dataset, so we will clean it from the set for analysis.
#
#
# The data had been crawled in april 2016, however we seee a fair portion of cars registered in 2017 and 2018 - which is providing false information.

# %% [markdown]
# #### Amending the registration year
# As acceptable value for registration year we will keeping the range of values from 1900 to 2016.

# %%
autos[autos['registration_year'].between(1900,2016)].describe()
# Out:
#               price  registration_year       powerPS    odometer_km  \
# count  3.660900e+04       36609.000000  36609.000000   36609.000000
# mean   7.680874e+03        2004.043596    130.149963  122262.831544
# std    2.520566e+04           7.017629    197.578657   40981.690248
# min    1.039000e+03        1927.000000      0.000000    5000.000000
# 25%    2.300000e+03        2001.000000     82.000000  100000.000000
# 50%    4.500000e+03        2005.000000    120.000000  150000.000000
# 75%    9.200000e+03        2008.000000    163.000000  150000.000000
# max    3.890000e+06        2016.000000  17700.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count        36609.000000         36609.0  36609.000000
# mean             6.060258             0.0  51883.379497
# std              3.567381             0.0  25669.470411
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  31319.000000
# 50%              6.000000             0.0  51065.000000
# 75%              9.000000             0.0  72654.000000
# max             12.000000             0.0  99998.000000

# %%
# inspecting pre-changes
autos['registration_year'].between(1900,2016).describe()
# Out:
# count     37992
# unique        2
# top        True
# freq      36609
# Name: registration_year, dtype: object

# %%
# amending with range of dates
autos = autos[autos['registration_year'].between(1900,2016) == True]

# %%
#verifying applied changes
autos['registration_year'].between(1900,2016).describe()
# Out:
# count     36609
# unique        1
# top        True
# freq      36609
# Name: registration_year, dtype: object

# %%
#inspecting the distribution of remainging values
autos['registration_year'].value_counts().sort_index(ascending=True)
# Out:
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
#         ...
# 2012    1306
# 2013     795
# 2014     649
# 2015     361
# 2016     623
# Name: registration_year, Length: 77, dtype: int64

# %% [markdown]
# ### Observations
#
#  - We reduced the number of rows in the dataset from 37992 to 36609 - a 3.64% percent reduction in the dataset. This we will denote as a small redcution, and conclude that we still have a dataset that can be properly analyzed.
#
#  - We can see a distribution with a long tail, with many cars registered around 2004/2005, with tails going in both directions. As expected there is a long historical tail.
#
#  - There is a number of old cars from 1944 downards - which are possibly collector car listings.
#
#  - 2016 has a spike of listings, and does not follow the decreasing trend from 2005 onwards - this is to be expected, as this bin would contain new rpdocution cars by dealers.

# %% [markdown]
# # 3. Exploring the data

# %% [markdown]
# We will now be looking to explore the dataset, that we have just prepared.

# %% [markdown]
# Firstly we will look at the the brand data for the ebay car sales, analysing the brand distribution.

# %%
autos['brand'].describe()
# Out:
# count          36609
# unique            40
# top       volkswagen
# freq            7711
# Name: brand, dtype: object

# %% [markdown]
# We se that we have 40 different brands across all listings.
# We will be focusing onbucketing of the top 20 most popular brands of cars.

# %%
autos['brand'].value_counts().head(20)
# Out:
# volkswagen        7711
# bmw               4623
# mercedes_benz     4115
# audi              3599
# opel              3235
# ford              2129
# renault           1342
# peugeot           1008
# fiat               767
# skoda              701
# seat               633
# smart              608
# toyota             538
# mazda              520
# citroen            505
# nissan             499
# mini               405
# hyundai            391
# sonstige_autos     382
# volvo              326
# Name: brand, dtype: int64

# %% [markdown]
# This narrows down our analysis whilst also containing the majoruity of the population.

# %%
population_count = autos['brand'].value_counts().head(20).sum() / autos['brand'].value_counts().sum()
print('The retained population is', population_count ,'%')
# Out:
# The retained population is 0.9297440520090688 %

# %% [markdown]
# We will store the list of the top20 brands in the list 'selected_brands'

# %%
#we store the table filtered by top 20 population
selected_brands = list(autos['brand'].value_counts().head(20).index)

# %% [markdown]
# ## Exploring the values of listing by brand

# %% [markdown]
# We will create a dictionary to analyse the mean values of listings, bucketed by brands.

# %%
brands_mean_values = {}

for brand in selected_brands:
    brands_mean_values[brand] = autos.loc[autos['brand'] == brand, 'price'].mean()

# %%
#sorting my highest to lowest mean
brands_mean_values
brand_mean_values_sorted = sorted(brands_mean_values.items(), key = lambda x: x[1], reverse = True)

for tuple in brand_mean_values_sorted:
    print(tuple)
# Out:
# ('sonstige_autos', 28282.25392670157)
# ('mini', 10715.237037037037)
# ('audi', 10405.156988052237)
# ('mercedes_benz', 9377.267314702309)
# ('bmw', 9191.208955223881)
# ('volkswagen', 7000.87718843211)
# ('skoda', 6903.306704707561)
# ('nissan', 6515.456913827656)
# ('hyundai', 6301.148337595908)
# ('volvo', 6278.003067484663)
# ('ford', 5912.610145608267)
# ('seat', 5711.921011058452)
# ('toyota', 5624.578066914498)
# ('mazda', 5392.401923076923)
# ('citroen', 4700.8712871287125)
# ('opel', 4298.587326120556)
# ('fiat', 4074.8487614080836)
# ('peugeot', 4043.121031746032)
# ('smart', 3826.2006578947367)
# ('renault', 3677.821907600596)

# %% [markdown]
# #### Key findings:
# - We see that 'mini', 'audi', 'mercedes_bez', and 'bmw' are the price leaers, and there is a large gap between bmw and the next price bucket of volkswagen (which average at around 7000, as measured aganst 9191 for bmw)
# - The range of values for the mean is between 10,715 and 3677 (excluding sonstige_autos).
# - 'sonstige_autos' is also an entry that is both relatively popular and high valued. This directly transaltes into 'other cars', and may inbclude a number of small, luxury car brands that exist in the market, hence being high on the mean price list.

# %% [markdown]
# ## Exploring the mileage
# We will create a dictionary to analyse the mileage of listings, bucketed by brands.

# %%
brands_mean_mileage = {} #store brand mean values

for brand in selected_brands:
    brands_mean_mileage[brand] = autos.loc[autos['brand'] == brand, 'odometer_km'].mean()

# %%
print(brands_mean_mileage)
# Out:
# {'volkswagen': 125481.77927635844, 'bmw': 131841.87756867835, 'mercedes_benz': 129924.66585662212, 'audi': 127453.4592942484, 'opel': 123588.87171561051, 'ford': 119069.98590887741, 'renault': 120916.54247391953, 'peugeot': 121676.58730158731, 'fiat': 107327.24902216428, 'skoda': 109643.36661911555, 'seat': 115663.50710900474, 'smart': 97409.53947368421, 'toyota': 113382.8996282528, 'mazda': 119451.92307692308, 'citroen': 113673.26732673268, 'nissan': 110220.44088176353, 'mini': 88679.01234567902, 'hyundai': 101240.40920716112, 'sonstige_autos': 88494.76439790576, 'volvo': 136917.17791411042}

# %% [markdown]
# ## Converting data back into Pandas structures

# %% [markdown]
# For more detailed analysis, rather than operating on dictionaries, we will import the data into a pandas structure, in particular we will import it into a series, using the pandas constructor commands

# %% [markdown]
# First we create the brand-value series

# %%
bmv_series = pd.Series(brands_mean_values)
type(bmv_series)
# Out:
# pandas.core.series.Series

# %%
bmv_series
# Out:
# volkswagen         7000.877188
# bmw                9191.208955
# mercedes_benz      9377.267315
# audi              10405.156988
# opel               4298.587326
# ford               5912.610146
# renault            3677.821908
# peugeot            4043.121032
# fiat               4074.848761
# skoda              6903.306705
# seat               5711.921011
# smart              3826.200658
# toyota             5624.578067
# mazda              5392.401923
# citroen            4700.871287
# nissan             6515.456914
# mini              10715.237037
# hyundai            6301.148338
# sonstige_autos    28282.253927
# volvo              6278.003067
# dtype: float64

# %% [markdown]
# Now we create the brand-mileage series

# %%
bmm_series = pd.Series(brands_mean_mileage)
type(bmm_series)
# Out:
# pandas.core.series.Series

# %%
bmm_series
# Out:
# volkswagen        125481.779276
# bmw               131841.877569
# mercedes_benz     129924.665857
# audi              127453.459294
# opel              123588.871716
# ford              119069.985909
# renault           120916.542474
# peugeot           121676.587302
# fiat              107327.249022
# skoda             109643.366619
# seat              115663.507109
# smart              97409.539474
# toyota            113382.899628
# mazda             119451.923077
# citroen           113673.267327
# nissan            110220.440882
# mini               88679.012346
# hyundai           101240.409207
# sonstige_autos     88494.764398
# volvo             136917.177914
# dtype: float64

# %% [markdown]
# Now we will join the two together, since we can use the brand name as key on which we can join them together.
# First setting up the dataframe, from the 'bmv_series'.

# %%
df = pd.DataFrame(bmv_series, columns =['mean_price'])

# %%
df['mileage'] = bmm_series

# %%
df
# Out:
#                   mean_price        mileage
# volkswagen       7000.877188  125481.779276
# bmw              9191.208955  131841.877569
# mercedes_benz    9377.267315  129924.665857
# audi            10405.156988  127453.459294
# opel             4298.587326  123588.871716
# ford             5912.610146  119069.985909
# renault          3677.821908  120916.542474
# peugeot          4043.121032  121676.587302
# fiat             4074.848761  107327.249022
# skoda            6903.306705  109643.366619
# seat             5711.921011  115663.507109
# smart            3826.200658   97409.539474
# toyota           5624.578067  113382.899628
# mazda            5392.401923  119451.923077
# citroen          4700.871287  113673.267327
# nissan           6515.456914  110220.440882
# mini            10715.237037   88679.012346
# hyundai          6301.148338  101240.409207
# sonstige_autos  28282.253927   88494.764398
# volvo            6278.003067  136917.177914

# %%
df.sort_values('mileage')
# Out:
#                   mean_price        mileage
# sonstige_autos  28282.253927   88494.764398
# mini            10715.237037   88679.012346
# smart            3826.200658   97409.539474
# hyundai          6301.148338  101240.409207
# fiat             4074.848761  107327.249022
# skoda            6903.306705  109643.366619
# nissan           6515.456914  110220.440882
# toyota           5624.578067  113382.899628
# citroen          4700.871287  113673.267327
# seat             5711.921011  115663.507109
# ford             5912.610146  119069.985909
# mazda            5392.401923  119451.923077
# renault          3677.821908  120916.542474
# peugeot          4043.121032  121676.587302
# opel             4298.587326  123588.871716
# volkswagen       7000.877188  125481.779276
# audi            10405.156988  127453.459294
# mercedes_benz    9377.267315  129924.665857
# bmw              9191.208955  131841.877569
# volvo            6278.003067  136917.177914

# %% [markdown]
# Looking at the correlation:

# %%
correlation = df['mean_price'].corr(df['mileage'])
print(correlation)
# Out:
# -0.3958288935205684

# %% [markdown]
# As expected we see a negative correlation on aggregate, however due to the bucketing, these values will have factors that will drive the correlation higher or lower. This inidicates that brand, or other factors will be at play when determining the price relationship of the car - which is to be expected.

# %% [markdown]
# # Translating categorical data
# In order to make the data more readable for an english-speaking audience, we will translate some of the categorical data into english.

# %% [markdown]
# We will do this by the means of mapping dictionaries. The below example translates the german 'ja' , 'nein' into english 'yes' and 'no' by the means of mapping dictionaries.

# %%
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
#        seller offer_type  price   abtest vehicle_type  registration_year  \
# 0      privat    Angebot   5000  control          bus               2004
# 1      privat    Angebot   8500  control    limousine               1997
# 2      privat    Angebot   8990     test    limousine               2009
# 3      privat    Angebot   4350  control   kleinwagen               2007
# 4      privat    Angebot   1350     test        kombi               2003
# ...       ...        ...    ...      ...          ...                ...
# 49995  privat    Angebot  24900  control    limousine               2011
# 49996  privat    Angebot   1980  control       cabrio               1996
# 49997  privat    Angebot  13200     test       cabrio               2014
# 49998  privat    Angebot  22900  control        kombi               2013
# 49999  privat    Angebot   1250  control    limousine               1996
#
#          gearbox  powerPS   model  odometer_km  registration_month fuel_type  \
# 0        manuell      158  andere       150000                   3       lpg
# 1      automatik      286     7er       150000                   6    benzin
# 2        manuell      102    golf        70000                   7    benzin
# 3      automatik       71  fortwo        70000                   6    benzin
# 4        manuell        0   focus       150000                   7    benzin
# ...          ...      ...     ...          ...                 ...       ...
# 49995  automatik      239      q5       100000                   1    diesel
# 49996    manuell       75   astra       150000                   5    benzin
# 49997  automatik       69     500         5000                  11    benzin
# 49998    manuell      150      a3        40000                  11    diesel
# 49999    manuell      101  vectra       150000                   1    benzin
#
#             brand unrepaired_damage           ad_created  nr_of_pictures  \
# 0         peugeot              nein  2016-03-26 00:00:00               0
# 1             bmw              nein  2016-04-04 00:00:00               0
# 2      volkswagen              nein  2016-03-26 00:00:00               0
# 3           smart              nein  2016-03-12 00:00:00               0
# 4            ford              nein  2016-04-01 00:00:00               0
# ...           ...               ...                  ...             ...
# 49995        audi              nein  2016-03-27 00:00:00               0
# 49996        opel              nein  2016-03-28 00:00:00               0
# 49997        fiat              nein  2016-04-02 00:00:00               0
# 49998        audi              nein  2016-03-08 00:00:00               0
# 49999        opel              nein  2016-03-13 00:00:00               0
#
#        postal_code            last_seen
# 0            79588  2016-04-06 06:45:54
# 1            71034  2016-04-06 14:45:08
# 2            35394  2016-04-06 20:15:37
# 3            33729  2016-03-15 03:16:28
# 4            39218  2016-04-01 14:38:50
# ...            ...                  ...
# 49995        82131  2016-04-01 13:47:40
# 49996        44807  2016-04-02 14:18:02
# 49997        73430  2016-04-04 11:47:27
# 49998        35683  2016-04-05 16:45:07
# 49999        45897  2016-04-06 21:18:48
#
# [36609 rows x 20 columns]

# %%
autos['unrepaired_damage'].value_counts()
# Out:
# nein    29389
# ja       2185
# Name: unrepaired_damage, dtype: int64

# %%
map1 = {
    'ja' : 'yes',
    'nein' : 'no'
}

# %%
autos['unrepaired_damage'] = autos['unrepaired_damage'].map(map1)

# %% [markdown]
# We repeat the process for other columns.

# %%
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
#        seller offer_type  price   abtest vehicle_type  registration_year  \
# 0      privat    Angebot   5000  control          bus               2004
# 1      privat    Angebot   8500  control    limousine               1997
# 2      privat    Angebot   8990     test    limousine               2009
# 3      privat    Angebot   4350  control   kleinwagen               2007
# 4      privat    Angebot   1350     test        kombi               2003
# ...       ...        ...    ...      ...          ...                ...
# 49995  privat    Angebot  24900  control    limousine               2011
# 49996  privat    Angebot   1980  control       cabrio               1996
# 49997  privat    Angebot  13200     test       cabrio               2014
# 49998  privat    Angebot  22900  control        kombi               2013
# 49999  privat    Angebot   1250  control    limousine               1996
#
#          gearbox  powerPS   model  odometer_km  registration_month fuel_type  \
# 0        manuell      158  andere       150000                   3       lpg
# 1      automatik      286     7er       150000                   6    benzin
# 2        manuell      102    golf        70000                   7    benzin
# 3      automatik       71  fortwo        70000                   6    benzin
# 4        manuell        0   focus       150000                   7    benzin
# ...          ...      ...     ...          ...                 ...       ...
# 49995  automatik      239      q5       100000                   1    diesel
# 49996    manuell       75   astra       150000                   5    benzin
# 49997  automatik       69     500         5000                  11    benzin
# 49998    manuell      150      a3        40000                  11    diesel
# 49999    manuell      101  vectra       150000                   1    benzin
#
#             brand unrepaired_damage           ad_created  nr_of_pictures  \
# 0         peugeot                no  2016-03-26 00:00:00               0
# 1             bmw                no  2016-04-04 00:00:00               0
# 2      volkswagen                no  2016-03-26 00:00:00               0
# 3           smart                no  2016-03-12 00:00:00               0
# 4            ford                no  2016-04-01 00:00:00               0
# ...           ...               ...                  ...             ...
# 49995        audi                no  2016-03-27 00:00:00               0
# 49996        opel                no  2016-03-28 00:00:00               0
# 49997        fiat                no  2016-04-02 00:00:00               0
# 49998        audi                no  2016-03-08 00:00:00               0
# 49999        opel                no  2016-03-13 00:00:00               0
#
#        postal_code            last_seen
# 0            79588  2016-04-06 06:45:54
# 1            71034  2016-04-06 14:45:08
# 2            35394  2016-04-06 20:15:37
# 3            33729  2016-03-15 03:16:28
# 4            39218  2016-04-01 14:38:50
# ...            ...                  ...
# 49995        82131  2016-04-01 13:47:40
# 49996        44807  2016-04-02 14:18:02
# 49997        73430  2016-04-04 11:47:27
# 49998        35683  2016-04-05 16:45:07
# 49999        45897  2016-04-06 21:18:48
#
# [36609 rows x 20 columns]

# %% [markdown]
# Inspecting the values with object inputs:

# %%
print(autos['seller'].value_counts())
print('\n')
print(autos['offer_type'].value_counts())
print('\n')
print(autos['abtest'].value_counts())
print('\n')
print(autos['vehicle_type'].value_counts())
print('\n')
print(autos['gearbox'].value_counts())
print('\n')
print(autos['fuel_type'].value_counts())
# Out:
# privat    36609
# Name: seller, dtype: int64
#
#
# Angebot    36609
# Name: offer_type, dtype: int64
#
#
# test       18879
# control    17730
# Name: abtest, dtype: int64
#
#
# limousine     10388
# kombi          7424
# kleinwagen     6662
# bus            3672
# cabrio         2839
# coupe          2153
# suv            1913
# andere          287
# Name: vehicle_type, dtype: int64
#
#
# manuell      26301
# automatik     9077
# Name: gearbox, dtype: int64
#
#
# benzin     20912
# diesel     13267
# lpg          556
# cng           58
# hybrid        37
# elektro       16
# andere         7
# Name: fuel_type, dtype: int64

# %% [markdown]
# We find that there are opportunities to translate from german to english. We will again to this by the means of mappings in pandas.

# %%
seller_map = {
    'privat' : 'private'
}

offer_type_map = {
    'Angebot' : 'offer'
}

#'abtest' column is directly translatable so will be omitted

vehicle_type_map = {
    'limousine' : 'limousine',
    'kombi' : 'kombi',
    'kleinwagen' : 'compact',
    'bus' : 'bus',
    'cabrio' : 'convertible',
    'coupe' : 'coupe',
    'suv' : 'suv',
    'andere' : 'other'
}

gearbox_map = {
    'manuell' : 'manual',
    'automatik' : 'automatic'
}

fuel_type_map = {
    'benzin' : 'gasoline',
    'diesel' : 'diesel',
    'lpg' : 'lpg',
    'cng' : 'cng',
    'hybrid' : 'hybrid',
    'elektro' : 'electric',
    'andere' : 'other' 
}

# %%
#applying the mapping

autos['seller'] = autos['seller'].map(seller_map)
autos['offer_type'] = autos['offer_type'].map(offer_type_map)
autos['vehicle_type'] = autos['vehicle_type'].map(vehicle_type_map)
autos['gearbox'] = autos['gearbox'].map(gearbox_map)
autos['fuel_type'] = autos['fuel_type'].map(fuel_type_map)

# %%
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
#         seller offer_type  price   abtest vehicle_type  registration_year  \
# 0      private      offer   5000  control          bus               2004
# 1      private      offer   8500  control    limousine               1997
# 2      private      offer   8990     test    limousine               2009
# 3      private      offer   4350  control      compact               2007
# 4      private      offer   1350     test        kombi               2003
# ...        ...        ...    ...      ...          ...                ...
# 49995  private      offer  24900  control    limousine               2011
# 49996  private      offer   1980  control  convertible               1996
# 49997  private      offer  13200     test  convertible               2014
# 49998  private      offer  22900  control        kombi               2013
# 49999  private      offer   1250  control    limousine               1996
#
#          gearbox  powerPS   model  odometer_km  registration_month fuel_type  \
# 0         manual      158  andere       150000                   3       lpg
# 1      automatic      286     7er       150000                   6  gasoline
# 2         manual      102    golf        70000                   7  gasoline
# 3      automatic       71  fortwo        70000                   6  gasoline
# 4         manual        0   focus       150000                   7  gasoline
# ...          ...      ...     ...          ...                 ...       ...
# 49995  automatic      239      q5       100000                   1    diesel
# 49996     manual       75   astra       150000                   5  gasoline
# 49997  automatic       69     500         5000                  11  gasoline
# 49998     manual      150      a3        40000                  11    diesel
# 49999     manual      101  vectra       150000                   1  gasoline
#
#             brand unrepaired_damage           ad_created  nr_of_pictures  \
# 0         peugeot                no  2016-03-26 00:00:00               0
# 1             bmw                no  2016-04-04 00:00:00               0
# 2      volkswagen                no  2016-03-26 00:00:00               0
# 3           smart                no  2016-03-12 00:00:00               0
# 4            ford                no  2016-04-01 00:00:00               0
# ...           ...               ...                  ...             ...
# 49995        audi                no  2016-03-27 00:00:00               0
# 49996        opel                no  2016-03-28 00:00:00               0
# 49997        fiat                no  2016-04-02 00:00:00               0
# 49998        audi                no  2016-03-08 00:00:00               0
# 49999        opel                no  2016-03-13 00:00:00               0
#
#        postal_code            last_seen
# 0            79588  2016-04-06 06:45:54
# 1            71034  2016-04-06 14:45:08
# 2            35394  2016-04-06 20:15:37
# 3            33729  2016-03-15 03:16:28
# 4            39218  2016-04-01 14:38:50
# ...            ...                  ...
# 49995        82131  2016-04-01 13:47:40
# 49996        44807  2016-04-02 14:18:02
# 49997        73430  2016-04-04 11:47:27
# 49998        35683  2016-04-05 16:45:07
# 49999        45897  2016-04-06 21:18:48
#
# [36609 rows x 20 columns]

# %% [markdown]
# This concludes our translation of categorical data.

# %% [markdown]
# ## Identifying categorical data

# %% [markdown]
# We will now look twards the name column, to see if there are any patterns in the 'name' columkn, to se whether we can extract an additional column.

# %%
print(autos['name'].value_counts())
# Out:
# BMW_320i                                                 67
# BMW_318i                                                 66
# Volkswagen_Golf_1.4                                      56
# BMW_316i                                                 54
# BMW_116i                                                 53
#                                                          ..
# Fiat_124_Eurospider_Pininfarina__Fiat____Garagenauto      1
# Touran_2.0_TDI_Highline_VOLL_140_PS_Bj_2004               1
# MINI_John_Cooper_Works_Cabrio_Chili_Paket_Top_Zustand     1
# A4_1.9_tdi_110_ps_19zoll_top                              1
# Ford_Puma_Sport                                           1
# Name: name, Length: 28015, dtype: int64

# %% [markdown]
# In order to make the analysis more efficient, we will perform keyword analysis.
# We note that:
#
# The seperator used between words is an underscore, rather than a space.
# The input is user generated, and can be any string of characters.
#
# In order to perform the keyword analysis we will seperate the entries into the list, and identify the most common keywords on the lists. We will also convert all to lower case to make the analysis consistent, as we do not need to  differentiate between capitalised words for this particular analysis.
#
# Then for each list we create a dicionary that counts the unique words.
#
# In order to do this, we use the 'Counter' library, which implements a simple function for counting unqie values for lists.

# %%
from collections import Counter
results = Counter()
autos['name'].str.lower().str.split('_').apply(results.update)
print(results)
# Out:
# Counter({'': 12817, 'volkswagen': 4496, 'bmw': 4416, 'tdi': 4243, 'mercedes': 3730, 'audi': 3406, '2.0': 3189, 'benz': 3089, 'opel': 3029, 'golf': 2892, 'dpf': 2667, '1.6': 2108, 'ford': 2043, 'vw': 1857, 'tüv': 1810, '1.4': 1798, '1': 1526, 'cdi': 1470, '1.9': 1409, '16v': 1349, 'mit': 1340, '1.2': 1332, 'neu': 1325, 'klima': 1274, 'automatik': 1260, 'renault': 1237, 'c': 1189, 'cabrio': 1155, 's': 1146, 'passat': 1146, 'top': 1144, '2': 1121, 'navi': 1119, 'edition': 1080, 'sport': 1076, 'a4': 1067, '1.8': 1037, '4': 967, 'astra': 963, 'peugeot': 961, 'polo': 941, 'avant': 914, 'variant': 892, 'tuev': 861, 'e': 855, 'smart': 846, 'touring': 796, '5': 791, 'corsa': 785, 'leder': 775, 'a6': 763, '/': 760, 'a3': 758, 'fiat': 742, 'coupe': 737, 't': 729, 'quattro': 728, 'xenon': 715, 'zustand': 699, 'aut.': 686, 'skoda': 679, 'ahk': 672, 'line': 663, 'kombi': 661, 'seat': 630, '200': 628, '6': 614, 'dsg': 611, 'm': 595, 'diesel': 592, 'tronic': 581, 'focus': 579, 'mini': 572, 'tsi': 565, '3.0': 559, 'ps': 558, 'highline': 545, 'comfortline': 543, 'avantgarde': 521, 'toyota': 514, 'mazda': 503, 'cdti': 493, 'd': 489, 'nissan': 484, 'elegance': 484, '8': 479, 'tdci': 474, 'a': 473, 'paket': 458, '3': 449, '320': 442, '220': 435, '7g': 431, 'lpg': 423, 'touran': 423, 'hand': 418, 'bis': 418, 'fiesta': 417, '1.0': 412, 'sehr': 407, '2.2': 407, 'zu': 398, 'v6': 397, 'verkaufe': 386, 'kompressor': 381, '2.5': 376, 'gepflegt': 374, 'hyundai': 373, '7': 371, '320d': 370, 'verkaufen': 362, 'km': 360, 'turbo': 359, 'zafira': 355, 'scheckheft': 353, '180': 347, 'dci': 334, '206': 332, 'citroën': 326, 'sportback': 325, 'classic': 322, 'gti': 321, 'und': 314, 'hdi': 312, 'volvo': 310, '9': 307, 'tfsi': 305, 'fortwo': 302, 'plus': 298, 'trendline': 295, 'mondeo': 294, 'turnier': 292, 'caravan': 292, 'vectra': 287, 'clio': 286, 'porsche': 286, 'combi': 286, 'ambiente': 286, 'cooper': 284, 'bluemotion': 281, 'cc': 281, '1.3': 280, 'kia': 279, 'twingo': 275, 't4': 274, 'voll': 268, 'punto': 266, 'fabia': 264, 'schwarz': 262, 'octavia': 260, 'style': 259, 'i': 259, 'honda': 259, 'cabriolet': 257, 'vollausstattung': 257, 'ibiza': 255, 'e46': 254, 'v': 253, 'bereift': 252, 'blueefficiency': 251, 'pdc': 251, 'sitzer': 250, '318i': 250, 'b': 250, 'fach': 247, '320i': 246, 'facelift': 243, 'ambition': 242, '0': 238, 'multivan': 235, 'amg': 232, 'chevrolet': 230, '4x4': 230, 'fsi': 229, 'mitsubishi': 227, 'alfa': 227, 'megane': 226, 'clk': 223, 'euro': 220, 'comfort': 218, '500': 216, '316i': 215, 'sportpaket': 212, 'suzuki': 207, 'titanium': 206, '110': 206, 'sharan': 202, 'bj': 202, 'romeo': 201, '350': 200, '4motion': 196, 'caddy': 195, 'exclusive': 194, 'in': 194, 'gepflegter': 192, 'garantie': 191, 'alu': 188, 'auto': 188, 'sitzheizung': 187, 'gruene': 187, 'grand': 186, 'tiptronic': 186, '525d': 185, 'fap': 185, 'lupo': 183, 'klasse': 183, 'tausch': 183, '+': 183, 'technology': 181, 'plakette': 181, 'leon': 180, 'benzin': 178, '530d': 176, '&': 174, 'roadster': 174, '75': 171, 'l': 171, 'h': 171, '1.hand': 171, 'panorama': 170, 't5': 169, 'g': 168, 'slk': 168, '2.4': 166, 'gt': 165, 'ausstattung': 165, '1.7': 162, 'trend': 158, '!': 157, 'limousine': 155, 'ghia': 155, 'ci': 155, 'crdi': 154, 'nur': 153, 'aus': 153, '2017': 152, '230': 150, 'ml': 149, '307': 149, 'multitronic': 149, 'standheizung': 149, '280': 149, '!!!': 148, '1.': 146, 'max': 146, '12v': 146, 'compact': 146, '1.5': 146, '2.7': 145, 'r': 145, '4matic': 144, 'e36': 144, 'wenig': 144, 'passion': 144, 'guter': 143, 'scenic': 142, 'super': 137, 'meriva': 137, 'lang': 137, '207': 136, 'tt': 136, '1.1': 135, 'citroen': 135, 'jahre': 134, 'motor': 133, '520i': 133, 'gang': 130, 'zoll': 130, 'micra': 129, 'sportline': 129, 'a5': 128, 'rover': 128, 'galaxy': 127, 'klimaautomatik': 127, 'schiebedach': 125, '170': 124, '270': 123, 'tourer': 123, '140': 122, '116i': 122, 'x': 122, 'yaris': 121, 'gasanlage': 121, '2.8': 120, 'iv': 120, 'tempomat': 120, 'dacia': 118, 'cd': 118, 'ka': 118, 'bee ...

# %% [markdown]
# We can see that the name will most often state the brand and make of the car. The list also counts popular german used to construct the ads.
#
# However, we also see words like 'klima', 'neu', and a number of '1.9', '2.5' , etc.
#
# This could indicate that we can potentially create categories for cars with AC, cars that are Brand New, and categorise by Cylinder Volume - as currently these columns do not exist.
#
# For the time being however, we will takes this out of the scope of the project, and note the possiblity for future exploration.
#
# This can also be taken as a suggestion for the German eBay interfrace for car listings - as there are no particualr columns for this information, people commonly implement the information into the advertisement name, which might indicate that there is demand for such information.

# %% [markdown]
# # Further Analysis

# %% [markdown]
# In the final part of the project we will conduct analysis on the following questions:

# %% [markdown]
# What are the most common brand/model combinations? <br>
# What is the distribution of prices around odometer values? <br>

# %% [markdown]
# ## What are the most common brand/model combinations?

# %% [markdown]
# In order to perform this analaysis we will create a list of tuples, where each tuple is of the form '(brand, model)'.
#
# Then we will count the number of unqiue brand model pairs, to identify the most common combinations.

# %% [markdown]
# First we isolate a dataframe, with only the relevant columns, and we will also convert the columns to string datatypes, so that we can apply the pandas operations to count up unique values.

# %%
s1 = autos['brand']
s1 = s1.astype("str")
s2 = autos['model']
s2 = s2.astype("str")


brandmodel = pd.concat([s1, s2], axis=1)
brandmodel
# Out:
#             brand   model
# 0         peugeot  andere
# 1             bmw     7er
# 2      volkswagen    golf
# 3           smart  fortwo
# 4            ford   focus
# ...           ...     ...
# 49995        audi      q5
# 49996        opel   astra
# 49997        fiat     500
# 49998        audi      a3
# 49999        opel  vectra
#
# [36609 rows x 2 columns]

# %% [markdown]
# Now we convert the the dataframe into a list of tuples

# %%
#converting to a list
brandmodel_list = brandmodel.values.tolist()

# %%
print(brandmodel_list)
# Out:
# [['peugeot', 'andere'], ['bmw', '7er'], ['volkswagen', 'golf'], ['smart', 'fortwo'], ['ford', 'focus'], ['chrysler', 'voyager'], ['volkswagen', 'golf'], ['smart', 'fortwo'], ['audi', 'a3'], ['renault', 'clio'], ['sonstige_autos', 'nan'], ['volkswagen', 'scirocco'], ['mazda', 'andere'], ['audi', 'a4'], ['porsche', '911'], ['mini', 'cooper'], ['peugeot', 'nan'], ['bmw', '5er'], ['mini', 'cooper'], ['mercedes_benz', 'e_klasse'], ['mercedes_benz', 'c_klasse'], ['audi', 'a3'], ['bmw', '5er'], ['ford', 'mondeo'], ['ford', 'mondeo'], ['seat', 'altea'], ['volkswagen', 'golf'], ['mercedes_benz', 'c_klasse'], ['volkswagen', 'golf'], ['volkswagen', 'nan'], ['volkswagen', 'polo'], ['audi', 'a1'], ['bmw', 'nan'], ['mercedes_benz', 'a_klasse'], ['mercedes_benz', 'c_klasse'], ['mercedes_benz', 'cl'], ['peugeot', '3_reihe'], ['mercedes_benz', 's_klasse'], ['opel', 'andere'], ['dacia', 'sandero'], ['ford', 'focus'], ['volkswagen', 'passat'], ['volkswagen', 'golf'], ['volkswagen', 'nan'], ['volkswagen', 'golf'], ['mini', 'cooper'], ['opel', 'corsa'], ['jeep', 'wrangler'], ['dacia', 'sandero'], ['saab', 'andere'], ['audi', 'a6'], ['volkswagen', 'transporter'], ['opel', 'astra'], ['volvo', 'andere'], ['bmw', '3er'], ['volvo', 'v40'], ['seat', 'ibiza'], ['nissan', 'micra'], ['bmw', '3er'], ['bmw', '1er'], ['toyota', 'yaris'], ['bmw', '5er'], ['audi', 'a6'], ['audi', 'a3'], ['bmw', '1er'], ['bmw', 'nan'], ['mazda', '6_reihe'], ['audi', 'a4'], ['jaguar', 'andere'], ['audi', 'a4'], ['mazda', '5_reihe'], ['nissan', 'micra'], ['volkswagen', 'transporter'], ['bmw', '5er'], ['mercedes_benz', 'vito'], ['seat', 'cordoba'], ['ford', 'galaxy'], ['audi', '100'], ['volkswagen', 'passat'], ['audi', 'a3'], ['opel', 'corsa'], ['audi', 'a4'], ['peugeot', '2_reihe'], ['volkswagen', 'golf'], ['ford', 'focus'], ['skoda', 'octavia'], ['mercedes_benz', 'm_klasse'], ['volkswagen', 'passat'], ['seat', 'altea'], ['peugeot', '2_reihe'], ['volkswagen', 'lupo'], ['nissan', 'primera'], ['audi', 'a3'], ['skoda', 'superb'], ['mercedes_benz', 'm_klasse'], ['mercedes_benz', 'e_klasse'], ['opel', 'meriva'], ['subaru', 'andere'], ['peugeot', '3_reihe'], ['ford', 'c_max'], ['mercedes_benz', 'e_klasse'], ['sonstige_autos', 'nan'], ['mercedes_benz', 'c_klasse'], ['audi', 'a4'], ['mercedes_benz', 'e_klasse'], ['renault', 'laguna'], ['volkswagen', 'golf'], ['sonstige_autos', 'nan'], ['porsche', 'andere'], ['volkswagen', 'transporter'], ['volkswagen', 'touran'], ['mercedes_benz', 'c_klasse'], ['opel', 'corsa'], ['mini', 'cooper'], ['bmw', 'm_reihe'], ['volkswagen', 'touareg'], ['fiat', 'andere'], ['audi', 'a4'], ['mercedes_benz', 'andere'], ['mercedes_benz', 'e_klasse'], ['volkswagen', 'golf'], ['audi', 'a4'], ['volkswagen', 'transporter'], ['audi', 'andere'], ['sonstige_autos', 'nan'], ['audi', 'a4'], ['volkswagen', 'touran'], ['mitsubishi', 'colt'], ['renault', 'megane'], ['smart', 'fortwo'], ['peugeot', '2_reihe'], ['renault', 'clio'], ['audi', 'nan'], ['toyota', 'avensis'], ['opel', 'vivaro'], ['fiat', 'nan'], ['bmw', 'x_reihe'], ['fiat', 'andere'], ['bmw', 'nan'], ['fiat', 'ducato'], ['renault', 'clio'], ['chevrolet', 'andere'], ['mazda', 'andere'], ['volkswagen', 'golf'], ['volkswagen', 'golf'], ['opel', 'tigra'], ['nissan', 'micra'], ['peugeot', '1_reihe'], ['bmw', '5er'], ['audi', 'a4'], ['porsche', 'boxster'], ['opel', 'signum'], ['volkswagen', 'sharan'], ['ford', 'focus'], ['volkswagen', 'golf'], ['porsche', 'andere'], ['nissan', 'micra'], ['opel', 'zafira'], ['ford', 'ka'], ['opel', 'astra'], ['ford', 'fiesta'], ['volkswagen', 'transporter'], ['toyota', 'rav'], ['audi', 'a5'], ['volkswagen', 'beetle'], ['volkswagen', 'touareg'], ['volvo', 'c_reihe'], ['volkswagen', 'phaeton'], ['hyundai', 'i_reihe'], ['mercedes_benz', 'nan'], ['volkswagen', 'touran'], ['mercedes_benz', 'sl'], ['mercedes_benz', 'c_klasse'], ['dacia', 'sandero'], ['audi', 'a6'], ['ford', 'focus'], ['peugeot', '3_reihe'], ['chevrolet', 'andere'], ['volkswagen', 'golf'], ['chrysler', 'andere'], ['opel', 'insignia' ...

# %% [markdown]
# We will now join each tuple into an individual string  , so that we have a series with countable inputs once we import this list into a dataframe.
#
# We do this, since the pandas built-in functions for counting unique values does not support lists.

# %%
brandmodel_list_str = []

for row in brandmodel_list:
    a = ' '.join(row)
    brandmodel_list_str.append(a)

# %%
brandmodel_list_str
# Out:
# ['peugeot andere',
#  'bmw 7er',
#  'volkswagen golf',
#  'smart fortwo',
#  'ford focus',
#  'chrysler voyager',
#  'volkswagen golf',
#  'smart fortwo',
#  'audi a3',
#  'renault clio',
#  'sonstige_autos nan',
#  'volkswagen scirocco',
#  'mazda andere',
#  'audi a4',
#  'porsche 911',
#  'mini cooper',
#  'peugeot nan',
#  'bmw 5er',
#  'mini cooper',
#  'mercedes_benz e_klasse',
#  'mercedes_benz c_klasse',
#  'audi a3',
#  'bmw 5er',
#  'ford mondeo',
#  'ford mondeo',
#  'seat altea',
#  'volkswagen golf',
#  'mercedes_benz c_klasse',
#  'volkswagen golf',
#  'volkswagen nan',
#  'volkswagen polo',
#  'audi a1',
#  'bmw nan',
#  'mercedes_benz a_klasse',
#  'mercedes_benz c_klasse',
#  'mercedes_benz cl',
#  'peugeot 3_reihe',
#  'mercedes_benz s_klasse',
#  'opel andere',
#  'dacia sandero',
#  'ford focus',
#  'volkswagen passat',
#  'volkswagen golf',
#  'volkswagen nan',
#  'volkswagen golf',
#  'mini cooper',
#  'opel corsa',
#  'jeep wrangler',
#  'dacia sandero',
#  'saab andere',
#  'audi a6',
#  'volkswagen transporter',
#  'opel astra',
#  'volvo andere',
#  'bmw 3er',
#  'volvo v40',
#  'seat ibiza',
#  'nissan micra',
#  'bmw 3er',
#  'bmw 1er',
#  'toyota yaris',
#  'bmw 5er',
#  'audi a6',
#  'audi a3',
#  'bmw 1er',
#  'bmw nan',
#  'mazda 6_reihe',
#  'audi a4',
#  'jaguar andere',
#  'audi a4',
#  'mazda 5_reihe',
#  'nissan micra',
#  'volkswagen transporter',
#  'bmw 5er',
#  'mercedes_benz vito',
#  'seat cordoba',
#  'ford galaxy',
#  'audi 100',
#  'volkswagen passat',
#  'audi a3',
#  'opel corsa',
#  'audi a4',
#  'peugeot 2_reihe',
#  'volkswagen golf',
#  'ford focus',
#  'skoda octavia',
#  'mercedes_benz m_klasse',
#  'volkswagen passat',
#  'seat altea',
#  'peugeot 2_reihe',
#  'volkswagen lupo',
#  'nissan primera',
#  'audi a3',
#  'skoda superb',
#  'mercedes_benz m_klasse',
#  'mercedes_benz e_klasse',
#  'opel meriva',
#  'subaru andere',
#  'peugeot 3_reihe',
#  'ford c_max',
#  'mercedes_benz e_klasse',
#  'sonstige_autos nan',
#  'mercedes_benz c_klasse',
#  'audi a4',
#  'mercedes_benz e_klasse',
#  'renault laguna',
#  'volkswagen golf',
#  'sonstige_autos nan',
#  'porsche andere',
#  'volkswagen transporter',
#  'volkswagen touran',
#  'mercedes_benz c_klasse',
#  'opel corsa',
#  'mini cooper',
#  'bmw m_reihe',
#  'volkswagen touareg',
#  'fiat andere',
#  'audi a4',
#  'mercedes_benz andere',
#  'mercedes_benz e_klasse',
#  'volkswagen golf',
#  'audi a4',
#  'volkswagen transporter',
#  'audi andere',
#  'sonstige_autos nan',
#  'audi a4',
#  'volkswagen touran',
#  'mitsubishi colt',
#  'renault megane',
#  'smart fortwo',
#  'peugeot 2_reihe',
#  'renault clio',
#  'audi nan',
#  'toyota avensis',
#  'opel vivaro',
#  'fiat nan',
#  'bmw x_reihe',
#  'fiat andere',
#  'bmw nan',
#  'fiat ducato',
#  'renault clio',
#  'chevrolet andere',
#  'mazda andere',
#  'volkswagen golf',
#  'volkswagen golf',
#  'opel tigra',
#  'nissan micra',
#  'peugeot 1_reihe',
#  'bmw 5er',
#  'audi a4',
#  'porsche boxster',
#  'opel signum',
#  'volkswagen sharan',
#  'ford focus',
#  'volkswagen golf',
#  'porsche andere',
#  'nissan micra',
#  'opel zafira',
#  'ford ka',
#  'opel astra',
#  'ford fiesta',
#  'volkswagen transporter',
#  'toyota rav',
#  'audi a5',
#  'volkswagen beetle',
#  'volkswagen touareg',
#  'volvo c_reihe',
#  'volkswagen phaeton',
#  'hyundai i_reihe',
#  'mercedes_benz nan',
#  'volkswagen touran',
#  'mercedes_benz sl',
#  'mercedes_benz c_klasse',
#  'dacia sandero',
#  'audi a6',
#  'ford focus',
#  'peugeot 3_reihe',
#  'chevrolet andere',
#  'volkswagen golf',
#  'chrysler andere',
#  'opel insignia',
#  'ford mondeo',
#  'volkswagen phaeton',
#  'volkswagen golf',
#  'volkswagen passat',
#  'ford mondeo',
#  'volkswagen up',
#  'honda civic',
#  'peugeot 2_reihe',
#  'mazda mx_reihe',
#  'smart fortwo',
#  'bmw x_reihe',
#  'audi a3',
#  'bmw 3er',
#  'audi a4',
#  'renault clio',
#  'kia sorento',
#  'smart fortwo',
#  'chrysler andere',
#  'audi a1',
#  'smart fortwo',
#  'opel corsa',
#  'opel corsa',
#  'volkswagen lupo',
#  'ford focus',
#  'bmw z_reihe',
#  'citroen berlingo',
#  'renault laguna',
#  'mercedes_benz e_klasse',
#  'volkswagen scirocco',
#  'mini cooper',
#  'mercedes_benz c_klasse',
#  'volkswagen golf',
#  'sonstige_autos nan',
#  'mercedes_benz c_klasse',
#  'mercedes_benz clk',
#  'bmw 3er',
#  'opel astra',
#  'volkswagen beetle',
#  'mercedes_benz e_klasse',
#  'audi a4',
#  'fiat punto',
#  'ford focus',
#  'volkswagen golf',
#  'bmw 3er',
#  'mercedes_benz e_klasse',
#  'ford s_max',
#  'bmw 1er',
#  'volkswagen golf',
#  'nissan micra',
#  'bmw 5er',
#  'audi a1',
#  'audi a4',
#  'bmw x_reihe',
#  'audi a3',
#  'toyota avensis',
#  'mazda cx_reihe',
#  'suzuki grand',
#  'suzuki swift',
#  'opel vivaro',
#  'mercedes_benz a_klasse',
#  'bmw 3er',
#  'smart fortwo',
#  'bmw 3er',
#  'audi a4',
#  'volkswagen tiguan',
#  'volkswagen golf',
#  'volkswagen golf',
#  'volkswagen golf',
#  'volkswagen transporter',
#  'ford focus',
#  'mercedes_benz sprinter',
#  'volkswagen golf',
#  'volkswagen golf',
#  'seat mii',
#  'volkswagen passat',
#  'ford focus',
#  'peugeot 3_reihe',
#  'volkswagen golf',
#  'mercedes_benz viano',
#  'mercedes_benz a_klasse',
#  'volkswagen kaefer',
#  'volkswagen scirocco',
#  'audi a4',
#  'opel astra',
#  'toyota avensis',
#  'volkswagen golf',
#  'mercedes_benz viano',
#  'volkswagen polo',
#  'bmw 3er',
#  'kia picanto',
#  'volkswagen golf',
#  'mazda mx_reihe',
#  'seat ibiza',
#  'mercedes_benz sprinter',
#  'volkswagen golf',
#  'volkswagen touran',
#  'audi a3',
#  'audi a6',
#  'ford galaxy',
#  'renault espace',
#  'trabant nan',
#  'audi a5',
#  'mercedes_benz m_klasse',
#  'audi a6',
#  'volkswagen transporter',
#  'mercedes_benz a_klasse',
#  'mercedes_benz c_klasse',
#  'mercedes_benz a_klasse',
#  'mini one',
#  'volkswagen bora',
#  'opel corsa',
#  'ford fiesta',
#  'opel corsa',
#  'bmw 5er',
#  'volkswagen golf',
#  'volkswagen golf',
#  'volkswagen golf',
#  'volkswagen fox',
#  'mercedes_benz s_klasse',
#  'ford mondeo',
#  'renault megane',
#  'audi a6',
#  'peugeot 3_reihe',
#  'mercedes_benz sprinter',
#  'volkswagen sharan',
#  'opel astra',
#  'volkswagen golf',
#  'mercedes_benz c_klasse',
#  'seat ibiza',
#  'bmw x_reihe',
#  'volkswagen passat',
#  'bmw 3er',
#  'volkswagen passat',
#  'audi a6',
#  'opel insignia',
#  'volkswagen polo',
#  'honda civic',
#  'mercedes_benz s_klasse',
#  'audi nan',
#  'volkswagen golf',
#  'porsche boxster',
#  'audi a4',
#  'mercedes_benz clk',
#  'peugeot 2_reihe',
#  'opel astra',
#  'hyundai i_reihe',
#  'bmw 3er',
#  'bmw 3er',
#  'mercedes_benz c_klasse',
#  'volkswagen polo',
#  'seat leon',
#  'mitsubishi colt',
#  'ford transit',
#  'renault andere',
#  'audi a4',
#  'bmw 5er',
#  'volkswagen golf',
#  'opel astra',
#  'mercedes_benz vito',
#  'volkswagen golf',
#  'hyundai tucson',
#  'smart fortwo',
#  'volkswagen golf',
#  'volkswagen golf',
#  'mazda andere',
#  'bmw 1er',
#  'audi tt',
#  'bmw 3er',
#  'chevrolet andere',
#  'volkswagen golf',
#  'ford mondeo',
#  'volkswagen golf',
#  'nissan qashqai',
#  'kia carnival',
#  'citroen nan',
#  'renault twingo',
#  'opel astra',
#  'seat leon',
#  'mercedes_benz m_klasse',
#  'mercedes_benz e_klasse',
#  'audi a6',
#  'ford focus',
#  'volkswagen transporter',
#  'smart fortwo',
#  'audi a4',
#  'jaguar andere',
#  'volkswagen golf',
#  'bmw 3er',
#  'audi a3',
#  'renault clio',
#  'mercedes_benz e_klasse',
#  'ford mustang',
#  'volkswagen golf',
#  'bmw 5er',
#  'ford focus',
#  'volkswagen golf',
#  'suzuki andere',
#  'bmw m_reihe',
#  'peugeot 2_reihe',
#  'audi andere',
#  'honda jazz',
#  'bmw 3er',
#  'mercedes_benz clk',
#  'mazda 6_reihe',
#  'mini cooper',
#  'opel astra',
#  'mercedes_benz e_klasse',
#  'nissan qashqai',
#  'mercedes_benz a_klasse',
#  'volkswagen passat',
#  'bmw 3er',
#  'ford galaxy',
#  'opel zafira',
#  'nissan almera',
#  'bmw nan',
#  'bmw 3er',
#  'opel corsa',
#  'mercedes_benz c_klasse',
#  'volkswagen scirocco',
#  'volkswagen sharan',
#  'audi a4',
#  'opel meriva',
#  'volkswagen golf',
#  'opel tigra',
#  'volkswagen andere',
#  'ford andere',
#  'toyota corolla',
#  'volkswagen golf',
#  'volkswagen nan',
#  'bmw 5er',
#  'porsche andere',
#  'audi a4',
#  'volkswagen touran',
#  'audi a4',
#  'volkswagen golf',
#  'opel vectra',
#  'volkswagen transporter',
#  'volvo v70',
#  'ford galaxy',
#  'renault megane',
#  'volkswagen golf',
#  'fiat andere',
#  'dacia duster',
#  'fiat stilo',
#  'subaru justy',
#  'dacia sandero',
#  'audi a3',
#  'volkswagen touran',
#  'toyota yaris',
#  'ford mondeo',
#  'mercedes_benz c_klasse',
#  'opel insignia',
#  'smart fortwo',
#  'volkswagen golf',
#  'mercedes_benz c_klasse',
#  'skoda fabia',
#  'mercedes_benz c_klasse',
#  'smart nan',
#  'sonstige_autos nan',
#  'volkswagen polo',
#  'mercedes_benz e_klasse',
#  'smart fortwo',
#  'mazda 6_reihe',
#  'volkswagen golf',
#  'nissan andere',
#  'audi a3',
#  'ford mondeo',
#  'mercedes_benz cl',
#  'volkswagen golf',
#  'chevrolet matiz',
#  'mercedes_benz c_klasse',
#  'peugeot andere',
#  'renault megane',
#  'volkswagen polo',
#  'opel omega',
#  'audi a4',
#  'mercedes_benz a_klasse',
#  'bmw 3er',
#  'audi a4',
#  'volkswagen touran',
#  'ford fiesta',
#  'opel corsa',
#  'volkswagen polo',
#  'audi tt',
#  'sonstige_autos nan',
#  'volkswagen polo',
#  'mercedes_benz c_klasse',
#  'land_rover freelander',
#  'mercedes_benz viano',
#  'volkswagen passat',
#  'opel vectra',
#  'volkswagen sharan',
#  'bmw 3er',
#  'kia picanto',
#  'audi a6',
#  'mitsubishi lancer',
#  'audi a4',
#  'chevrolet andere',
#  'audi a1',
#  'opel vivaro',
#  'mini one',
#  'toyota andere',
#  'ford mondeo',
#  'ford focus',
#  'volkswagen fox',
#  'volkswagen golf',
#  'bmw nan',
#  'volkswagen polo',
#  'audi a3',
#  'audi a3',
#  'volkswagen transporter',
#  'volkswagen transporter',
#  'audi a6',
#  'mercedes_benz sprinter',
#  'bmw 3er',
#  'opel meriva',
#  'ford andere',
#  'volkswagen golf',
#  'mazda 6_reihe',
#  'volkswagen transporter',
#  'jeep nan',
#  'honda jazz',
#  'bmw andere',
#  'skoda octavia',
#  'volkswagen passat',
#  'volkswagen golf',
#  'volkswagen polo',
#  'volkswagen passat',
#  'smart fortwo',
#  'bmw 7er',
#  'mercedes_benz andere',
#  'mercedes_benz a_klasse',
#  'ford galaxy',
#  'subaru forester',
#  'suzuki grand',
#  'volkswagen polo',
#  'bmw 1er',
#  'jaguar s_type',
#  'bmw 5er',
#  'bmw 3er',
#  'volkswagen passat',
#  'mazda mx_reihe',
#  'renault andere',
#  'fiat bravo',
#  'volkswagen transporter',
#  'bmw 3er',
#  'volkswagen golf',
#  'opel zafira',
#  'renault nan',
#  'peugeot 1_reihe',
#  'bmw 3er',
#  'bmw 3er',
#  'audi a3',
#  'bmw 5er',
#  'mercedes_benz c_klasse',
#  'fiat 500',
#  'smart fortwo',
#  'volkswagen transporter',
#  'volvo v40',
#  'alfa_romeo 156',
#  'bmw 3er',
#  'opel corsa',
#  'honda cr_reihe',
#  'fiat stilo',
#  'peugeot 3_reihe',
#  'volkswagen sharan',
#  'renault scenic',
#  'audi a6',
#  'ford focus',
#  'seat toledo',
#  'opel corsa',
#  'bmw 3er',
#  'volkswagen golf',
#  'alfa_romeo andere',
#  'volkswagen polo',
#  'mercedes_benz a_klasse',
#  'bmw 1er',
#  'mazda nan',
#  'mercedes_benz c_klasse',
#  'opel meriva',
#  'opel astra',
#  'mercedes_benz sl',
#  'renault clio',
#  'bmw 3er',
#  'ford focus',
#  'nissan andere',
#  'bmw 3er',
#  'volkswagen polo',
#  'toyota andere',
#  'volkswagen golf',
#  'audi a4',
#  'mercedes_benz c_klasse',
#  'volkswagen golf',
#  'nissan almera',
#  'audi a8',
#  'opel corsa',
#  'toyota yaris',
#  'audi a3',
#  'mercedes_benz c_klasse',
#  'volkswagen golf',
#  'fiat punto',
#  'mercedes_benz andere',
#  'skoda octavia',
#  'bmw x_reihe',
#  'seat cordoba',
#  'opel astra',
#  'kia ceed',
#  'ford mondeo',
#  'volkswagen passat',
#  'opel tigra',
#  'volkswagen transporter',
#  'mercedes_benz e_klasse',
#  'renault twingo',
#  'volkswagen polo',
#  'volkswagen transporter',
#  'bmw 3er',
#  'nissan andere',
#  'mercedes_benz c_klasse',
#  'audi andere',
#  'peugeot 5_reihe',
#  'smart fortwo',
#  'volkswagen caddy',
#  'dacia sandero',
#  'toyota aygo',
#  'opel astra',
#  'volkswagen caddy',
#  'fiat stilo',
#  'audi a6',
#  'bmw 3er',
#  'volkswagen golf',
#  'audi andere',
#  'opel signum',
#  'mercedes_benz c_klasse',
#  'volkswagen bora',
#  'kia ceed',
#  'audi a4',
#  'volkswagen touran',
#  'mercedes_benz e_klasse',
#  'audi a4',
#  'audi andere',
#  'bmw 3er',
#  'mercedes_benz clk',
#  'hyundai i_reihe',
#  'mercedes_benz sprinter',
#  'hyundai nan',
#  'volkswagen lupo',
#  'volkswagen golf',
#  'skoda citigo',
#  'volkswagen golf',
#  'seat exeo',
#  'renault megane',
#  'citroen c1',
#  'mercedes_benz sprinter',
#  'nissan almera',
#  'volkswagen nan',
#  'sonstige_autos nan',
#  'hyundai i_reihe',
#  'opel vivaro',
#  'mercedes_benz andere',
#  'volkswagen polo',
#  'renault kangoo',
#  'audi a6',
#  'mercedes_benz a_klasse',
#  'volvo v40',
#  'volkswagen bora',
#  'smart fortwo',
#  'audi a4',
#  'renault laguna',
#  'opel zafira',
#  'audi a4',
#  'bmw 3er',
#  'fiat doblo',
#  'hyundai i_reihe',
#  'seat toledo',
#  'ford c_max',
#  'volkswagen golf',
#  'mercedes_benz e_klasse',
#  'subaru impreza',
#  'volkswagen golf',
#  'bmw 3er',
#  'audi a3',
#  'citroen andere',
#  'mercedes_benz c_klasse',
#  'opel nan',
#  'volkswagen polo',
#  'volkswagen passat',
#  'volkswagen transporter',
#  'chevrolet andere',
#  'volkswagen sharan',
#  'volkswagen golf',
#  'volkswagen beetle',
#  'volkswagen bora',
#  'mercedes_benz e_klasse',
#  'nissan almera',
#  'volkswagen lupo',
#  'seat leon',
#  'mercedes_benz a_klasse',
#  'opel vectra',
#  'audi a4',
#  'opel astra',
#  'audi a3',
#  'mercedes_benz e_klasse',
#  'bmw 3er',
#  'mercedes_benz e_klasse',
#  'volkswagen sharan',
#  'renault megane',
#  'seat ibiza',
#  'volkswagen golf',
#  'volkswagen polo',
#  'bmw 3er',
#  'chevrolet nan',
#  'audi a3',
#  'bmw 3er',
#  'mercedes_benz nan',
#  'volkswagen beetle',
#  'citroen berlingo',
#  'audi a4',
#  'bmw 3er',
#  'hyundai andere',
#  'citroen andere',
#  'opel corsa',
#  'nissan micra',
#  'volkswagen passat',
#  'subaru justy',
#  'volkswagen golf',
#  'toyota andere',
#  'toyota corolla',
#  'hyundai andere',
#  'audi a4',
#  'volkswagen passat',
#  'opel zafira',
#  'chevrolet andere',
#  'ford focus',
#  'audi a6',
#  'volkswagen polo',
#  'fiat doblo',
#  'bmw 5er',
#  'renault clio',
#  'bmw 1er',
#  'ford galaxy',
#  'volkswagen golf',
#  'smart fortwo',
#  'mercedes_benz e_klasse',
#  'mini cooper',
#  'mercedes_benz a_klasse',
#  'volkswagen bora',
#  'mini cooper',
#  'ford ka',
#  'opel zafira',
#  'mercedes_benz e_klasse',
#  'ford s_max',
#  'mercedes_benz a_klasse',
#  'volkswagen polo',
#  'smart fortwo',
#  'mercedes_benz c_klasse',
#  'fiat doblo',
#  'opel astra',
#  'renault nan',
#  'bmw 1er',
#  'volkswagen transporter',
#  'bmw 3er',
#  'bmw 3er',
#  'bmw 1er',
#  'bmw 3er',
#  'ford focus',
#  'audi a4',
#  'peugeot 2_reihe',
#  'audi a3',
#  'volkswagen passat',
#  'hyundai andere',
#  'toyota aygo',
#  'hyundai andere',
#  'audi tt',
#  'volkswagen golf',
#  'opel andere',
#  'volkswagen golf',
#  'audi a3',
#  'opel andere',
#  'audi a4',
#  'audi a6',
#  'skoda nan',
#  'opel corsa',
#  'renault kangoo',
#  'audi tt',
#  'sonstige_autos nan',
#  'mercedes_benz e_klasse',
#  'alfa_romeo 145',
#  'mercedes_benz e_klasse',
#  'mercedes_benz a_klasse',
#  'audi a5',
#  'volkswagen polo',
#  'bmw 3er',
#  'volkswagen polo',
#  'volkswagen touran',
#  'citroen c3',
#  'mercedes_benz e_klasse',
#  'bmw 3er',
#  'mercedes_benz c_klasse',
#  'volkswagen golf',
#  'renault twingo',
#  'mercedes_benz a_klasse',
#  'sonstige_autos nan',
#  'peugeot 1_reihe',
#  'mercedes_benz andere',
#  'volkswagen polo',
#  'volkswagen golf',
#  'mercedes_benz s_klasse',
#  'bmw 5er',
#  'hyundai andere',
#  'opel zafira',
#  'mercedes_benz e_klasse',
#  'volkswagen golf',
#  'mercedes_benz andere',
#  'bmw 1er',
#  'skoda roomster',
#  'volkswagen golf',
#  'opel vectra',
#  'peugeot 2_reihe',
#  'toyota auris',
#  'honda civic',
#  'trabant 601',
#  'smart fortwo',
#  'ford fiesta',
#  'fiat panda',
#  'suzuki andere',
#  'volkswagen passat',
#  'fiat stilo',
#  'bmw 1er',
#  'mercedes_benz nan',
#  'volkswagen passat',
#  'ford ka',
#  'volkswagen golf',
#  'volkswagen fox',
#  'bmw 3er',
#  'volkswagen golf',
#  'ford fiesta',
#  'volkswagen eos',
#  'chevrolet aveo',
#  'hyundai andere',
#  'volkswagen passat',
#  'audi a3',
#  'mercedes_benz slk',
#  'volkswagen passat',
#  'daihatsu terios',
#  'seat nan',
#  'bmw 5er',
#  'volkswagen touran',
#  'peugeot andere',
#  'kia sorento',
#  'volkswagen golf',
#  'suzuki andere',
#  'peugeot 3_reihe',
#  'audi a6',
#  'volkswagen passat',
#  'bmw m_reihe',
#  'ford transit',
#  'volvo v40',
#  'sonstige_autos nan',
#  'fiat stilo',
#  'volkswagen touran',
#  'citroen c1',
#  'volkswagen golf',
#  'fiat punto',
#  'volkswagen tiguan',
#  'mercedes_benz a_klasse',
#  'volkswagen polo',
#  'mercedes_benz andere',
#  'mercedes_benz a_klasse',
#  'hyundai tucson',
#  'opel astra',
#  'volkswagen passat',
#  'bmw 5er',
#  'ford mondeo',
#  'volkswagen passat',
#  'volkswagen golf',
#  'mercedes_benz e_klasse',
#  'renault megane',
#  'opel signum',
#  'volkswagen golf',
#  'ford fusion',
#  'bmw 1er',
#  'audi a3',
#  'smart fortwo',
#  'skoda octavia',
#  'renault clio',
#  'bmw 5er',
#  'volkswagen nan',
#  'suzuki andere',
#  'citroen c4',
#  'fiat 500',
#  'chrysler voyager',
#  'porsche boxster',
#  'volkswagen golf',
#  'volkswagen golf',
#  'seat ibiza',
#  'opel astra',
#  'volkswagen sharan',
#  'mini cooper',
#  'volkswagen caddy',
#  'mercedes_benz glk',
#  'audi a6',
#  'bmw 3er',
#  'opel vectra',
#  'opel vivaro',
#  'audi a3',
#  'smart fortwo',
#  'opel astra',
#  'renault clio',
#  'daihatsu materia',
#  'bmw nan',
#  'volkswagen touran',
#  'mercedes_benz c_klasse',
#  'renault clio',
#  'skoda andere',
#  'peugeot 3_reihe',
#  'volkswagen touareg',
#  'peugeot 2_reihe',
#  'mercedes_benz a_klasse',
#  'mercedes_benz c_klasse',
#  'volkswagen fox',
#  'volkswagen touran',
#  'volkswagen golf',
#  'opel astra',
#  'bmw 7er',
#  'ford focus',
#  'volkswagen caddy',
#  'mercedes_benz andere',
#  'volkswagen golf',
#  'volvo v50',
#  'volkswagen golf',
#  'mercedes_benz nan',
#  'volkswagen polo',
#  'volkswagen passat',
#  'nissan qashqai',
#  'bmw 3er',
#  'ford focus',
#  'bmw 3er',
#  'opel combo',
#  'opel astra',
#  'bmw 3er',
#  'bmw z_reihe',
#  'chevrolet matiz',
#  'bmw 3er',
#  'bmw 3er',
#  'volkswagen sharan',
#  'fiat doblo',
#  'bmw 1er',
#  'bmw 3er',
#  'mercedes_benz c_klasse',
#  'skoda yeti',
#  'volkswagen golf',
#  'ford focus',
#  'bmw 3er',
#  'bmw 3er',
#  'peugeot nan',
#  'renault clio',
#  'volkswagen beetle',
#  'opel astra',
#  'volkswagen scirocco',
#  'mercedes_benz e_klasse',
#  'renault clio',
#  'volkswagen golf',
#  'mazda 6_reihe',
#  'volvo v40',
#  'opel corsa',
#  'peugeot 3_reihe',
#  'volkswagen golf',
#  'volkswagen golf',
#  'volkswagen lupo',
#  'renault twingo',
#  'volvo v70',
#  'bmw 3er',
#  'opel meriva',
#  'audi a3',
#  'mazda mx_reihe',
#  'opel astra',
#  'mercedes_benz e_klasse',
#  'volkswagen nan',
#  'saab 900',
#  'opel corsa',
#  'kia sorento',
#  'volkswagen golf',
#  'nissan qashqai',
#  'audi 80',
#  'volkswagen golf',
#  'mercedes_benz viano',
#  'renault megane',
#  'opel omega',
#  'volkswagen golf',
#  'skoda fabia',
#  'volkswagen polo',
#  'bmw 5er',
#  'mercedes_benz andere',
#  'bmw 3er',
#  'bmw 5er',
#  'volkswagen golf',
#  'mini one',
#  'sonstige_autos nan',
#  'bmw 3er',
#  'bmw 3er',
#  'opel corsa',
#  'bmw 3er',
#  'mercedes_benz clk',
#  'volvo v70',
#  'skoda octavia',
#  'skoda yeti',
#  'porsche andere',
#  'skoda yeti',
#  'audi a6',
#  'audi a4',
#  'mini cooper',
#  'opel vectra',
#  'bmw 3er',
#  'opel signum',
#  'chevrolet matiz',
#  'opel vectra',
#  'opel insignia',
#  'volkswagen fox',
#  'audi a4',
#  ...]

# %% [markdown]
# We now convert the list into a dataframe.

# %%
brandmodel_series = pd.Series(brandmodel_list_str)

# %%
brandmodel_series
# Out:
# 0         peugeot andere
# 1                bmw 7er
# 2        volkswagen golf
# 3           smart fortwo
# 4             ford focus
#               ...
# 36604            audi q5
# 36605         opel astra
# 36606           fiat 500
# 36607            audi a3
# 36608        opel vectra
# Length: 36609, dtype: object

# %% [markdown]
# Now counting the unique values in the dataframe, to obtain the most popular combinations.

# %%
brandmodel_series.value_counts()
# Out:
# volkswagen golf      2865
# bmw 3er              2262
# volkswagen passat    1136
# audi a4              1079
# bmw 5er              1053
#                      ...
# rover nan               1
# alfa_romeo 145          1
# rover rangerover        1
# daewoo lanos            1
# lada samara             1
# Length: 325, dtype: int64

# %% [markdown]
# We see that the 20 popular combinations are as follows:

# %%
brandmodel_series.value_counts().head(20)
# Out:
# volkswagen golf           2865
# bmw 3er                   2262
# volkswagen passat         1136
# audi a4                   1079
# bmw 5er                   1053
# mercedes_benz c_klasse    1026
# opel astra                 960
# volkswagen polo            920
# mercedes_benz e_klasse     882
# opel corsa                 798
# audi a3                    762
# audi a6                    751
# volkswagen transporter     641
# ford focus                 567
# bmw 1er                    511
# smart fortwo               507
# peugeot 2_reihe            493
# volkswagen touran          433
# mercedes_benz a_klasse     433
# ford fiesta                420
# dtype: int64

# %% [markdown]
# ### What is the distribution of prices around odometer values?

# %% [markdown]
# In this part we will want to gain a better understanding o the relationship between mileage on  car at point of sale and the price of the car.
#
# We will create a dsitribution of prices over odometer values. Note that this analysis only analyzes the two factors, and we acknowledge that brand and other factorts will affect this relationship.

# %% [markdown]
# Firstly lookng at the range of values for mileage:

# %%
autos['odometer_km'].value_counts()
# Out:
# 150000    21846
# 125000     4138
# 100000     1809
# 90000      1509
# 80000      1288
# 70000      1127
# 60000      1067
# 50000       963
# 40000       777
# 30000       730
# 20000       675
# 5000        464
# 10000       216
# Name: odometer_km, dtype: int64

# %% [markdown]
# we see that there is a limited number of integer inputs for the mileage values:
# from 5000 to 150,000.
#
# We will use these as bins for our distribution.

# %%
bins = autos['odometer_km'].unique()
bins.sort() #sort ascending for readability
print(bins)
# Out:
# [  5000  10000  20000  30000  40000  50000  60000  70000  80000  90000
#  100000 125000 150000]

# %% [markdown]
# We will compute the mean price for each odometer value in the list

# %%
price_odometer_distribution = {}

for row in bins:
    prices = autos.loc[autos['odometer_km'] == row, 'price'].mean()
    price_odometer_distribution[row] = prices

# %%
price_odometer_distribution
# Out:
# {5000: 23132.717672413793,
#  10000: 22885.77314814815,
#  20000: 20227.11703703704,
#  30000: 17271.686301369864,
#  40000: 15884.168597168597,
#  50000: 15575.245067497404,
#  60000: 13060.59418931584,
#  70000: 11479.026619343389,
#  80000: 10335.17857142857,
#  90000: 9317.526838966203,
#  100000: 9170.264234383638,
#  125000: 7425.746254229096,
#  150000: 5051.199761970155}

# %% [markdown]
# We will represent this using a bar chart for the distribution using the matplotlib libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

s2 = pd.Series(price_odometer_distribution)

# %%
s2
# Out:
# 5000      23132.717672
# 10000     22885.773148
# 20000     20227.117037
# 30000     17271.686301
# 40000     15884.168597
# 50000     15575.245067
# 60000     13060.594189
# 70000     11479.026619
# 80000     10335.178571
# 90000      9317.526839
# 100000     9170.264234
# 125000     7425.746254
# 150000     5051.199762
# dtype: float64

# %%
s2.plot.bar()

# %% [markdown]
# We can see that there is a negative relationship beteween price abnd odometer values - as expected.
#
# The vaues plateaue at the 5000 - 1000 range, where the prices are at a similar range in both bins (at 23132 and 22885 averages respectively).
#
# A similar plateau is found for mileages between 40 000 and 50 000 (with mean prices respectively at ( 15884.16 and 15575.24).
#
# There is a signifact values in cars with mileages in the 150 000 bin. This is expected as this bin will also inclde cars with extremely high mileage, which we would expect to significantly decrease the value of the car, as well as the likelihood of it needing repairs

# %% [markdown]
# # Summary
#
# We had worked on the dataset for eBay car sales data for the German Auto eBay website.
#
# We had organised and cleaned the data into a dataframe, in order to make it usable for data analysis. We had removed outliers, and selected ranges for data that fit our expectations. We had also performed datatype conversions, as well as language translations in order to make the data readable, and accessible for a deeper analysis.
#
# We had looked at the relationships of price, brand and mileage and drawn preliminary conclusions.
